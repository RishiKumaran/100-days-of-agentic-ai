# %% [markdown]
# # Welcome to the start of your adventure in Agentic AI

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/stop.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Are you ready for action??</h2>
#             <span style="color:#ff7800;">Have you completed all the setup steps in the <a href="../setup/">setup</a> folder?<br/>
#             Have you read the <a href="../README.md">README</a>? Many common questions are answered here!<br/>
#             Have you checked out the guides in the <a href="../guides/01_intro.ipynb">guides</a> folder?<br/>
#             Well in that case, you're ready!!
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/tools.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#00bfff;">This code is a live resource - keep an eye out for my updates</h2>
#             <span style="color:#00bfff;">I push updates regularly. As people ask questions or have problems, I add more examples and improve explanations. As a result, the code below might not be identical to the videos, as I've added more steps and better comments. Consider this like an interactive book that accompanies the lectures.<br/><br/>
#             I try to send emails regularly with important updates related to the course. You can find this in the 'Announcements' section of Udemy in the left sidebar. You can also choose to receive my emails via your Notification Settings in Udemy. I'm respectful of your inbox and always try to add value with my emails!
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# ### And please do remember to contact me if I can help
#
# And I love to connect: https://www.linkedin.com/in/eddonner/
#
#
# ### New to Notebooks like this one? Head over to the guides folder!
#
# Just to check you've already added the Python and Jupyter extensions to Cursor, if not already installed:
# - Open extensions (View >> extensions)
# - Search for python, and when the results show, click on the ms-python one, and Install it if not already installed
# - Search for jupyter, and when the results show, click on the Microsoft one, and Install it if not already installed
# Then View >> Explorer to bring back the File Explorer.
#
# And then:
# 1. Click where it says "Select Kernel" near the top right, and select the option called `.venv (Python 3.12.12)` or similar, which should be the first choice or the most prominent choice. You may need to choose "Python Environments" first.
# 2. Click in each "cell" below, starting with the cell immediately below this text, and press Shift+Enter to run
# 3. Enjoy!
#
# After you click "Select Kernel", if there is no option like `.venv (Python 3.12.12)` then please do the following:
# 1. On Mac: From the Cursor menu, choose Settings >> VS Code Settings (NOTE: be sure to select `VSCode Settings` not `Cursor Settings`);
# On Windows PC: From the File menu, choose Preferences >> VS Code Settings(NOTE: be sure to select `VSCode Settings` not `Cursor Settings`)
# 2. In the Settings search bar, type "venv"
# 3. In the field "Path to folder with a list of Virtual Environments" put the path to the project root, like C:\Users\username\projects\agents (on a Windows PC) or /Users/username/projects/agents (on Mac or Linux).
# And then try again.

# %%
# First let's do an import. If you get an Import Error, see Q5 and then Q25 here: https://edwarddonner.com/avatar

from dotenv import load_dotenv

# %%
# Next it's time to load the API keys into environment variables
# If this returns false, see the next cell!

load_dotenv(override=True)
# Out:
# True

# %% [markdown]
# ### Wait, did that just output `False`??
#
# If so, the most common reason is that you didn't save your `.env` file after adding the key! Be sure to have saved.
#
# Also, make sure the `.env` file is named precisely `.env` and is in the project root directory (`agents`)
#
# By the way, your `.env` file might have a stop symbol next to it in Cursor on the left, and that's actually a good thing: that's Cursor saying to you, "hey, I realize this is a file filled with secret information, and I'm not going to send it to an external AI to suggest changes, because your keys should not be shown to anyone else."

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/stop.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Final reminders</h2>
#             <span style="color:#ff7800;">1. If you're not confident about Environment Variables or Web Endpoints / APIs, please read Topics 3 and 5 in this <a href="../guides/04_technical_foundations.ipynb">technical foundations guide</a>.<br/>
#             2. If you want to use AIs other than OpenAI, like Gemini, DeepSeek or Ollama (free), please see the first section in this <a href="../guides/09_ai_apis_and_ollama.ipynb">AI APIs guide</a>.<br/>
#             3. If you ever get a Name Error in Python, you can always fix it immediately; see the last section of this <a href="../guides/06_python_foundations.ipynb">Python Foundations guide</a> and follow both tutorials and exercises.<br/>
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# Check the key - if you're not using OpenAI, check whichever key you're using! Ollama doesn't need a key.

import os

# %%
# And now - the all important import statement
# If you get an import error - head over to Q5 and Q25 in the FAQ at https://edwarddonner.com/avatar
# Even for other LLM providers like Gemini, you still use this OpenAI import - see Guide 9 for why

from openai import OpenAI

# %%
# And now we'll create an instance of the OpenAI class
# If you're not sure what it means to create an instance of a class - head over to the guides folder (guide 6)!
# If you get a NameError - head over to the guides folder (guide 6)to learn about NameErrors - always instantly fixable
# If you're not using OpenAI, you just need to slightly modify this - precise instructions are in the AI APIs guide (guide 9)

openai = OpenAI()
# Out:
# ---------------------------------------------------------------------------
# OpenAIError                               Traceback (most recent call last)
# Cell In[15], line 6
#       2 # If you're not sure what it means to create an instance of a class - head over to the guides folder (guide 6)!
#       3 # If you get a NameError - head over to the guides folder (guide 6)to learn about NameErrors - always instantly fixable
#       4 # If you're not using OpenAI, you just need to slightly modify this - precise instructions are in the AI APIs guide (guide 9)
#       5
# ----> 6 openai = OpenAI()
#       7 GEMINI_BASE_URL = "https://generativelanguage.googleapis.com/v1beta/openai/"
#       8
#       9 google_api_key = os.getenv("GOOGLE_API_KEY")
#
# File ~/Documents/GitHub/Agentic Ai /agents/.venv/lib/python3.12/site-packages/openai/_client.py:194, in OpenAI.__init__(self, api_key, admin_api_key, workload_identity, organization, project, webhook_secret, base_url, websocket_base_url, timeout, max_retries, default_headers, default_query, http_client, _strict_response_validation, _enforce_credentials)
#     185 self.admin_api_key = admin_api_key
#     187 if (
#     188     _enforce_credentials
#     189     and not self.api_key
#    (...)    192     and self.admin_api_key is None
#     193 ):
# --> 194     raise OpenAIError(
#     195         "Missing credentials. Please pass an `api_key`, `workload_identity`, `admin_api_key`, or set the `OPENAI_API_KEY` or `OPENAI_ADMIN_KEY` environment variable."
#     196     )
#     198 if organization is None:
#     199     organization = os.environ.get("OPENAI_ORG_ID")
#
# OpenAIError: Missing credentials. Please pass an `api_key`, `workload_identity`, `admin_api_key`, or set the `OPENAI_API_KEY` or `OPENAI_ADMIN_KEY` environment variable.

# %%
# Create a list of messages in the familiar OpenAI format

messages = [{"role": "user", "content": "Tell me a fun fact"}]

# %%
messages
# Out:
# [{'role': 'user', 'content': 'Tell me a fun fact'}]

# %%
import os
load_dotenv(override=True)

GEMINI_BASE_URL = "https://generativelanguage.googleapis.com/v1beta/openai/"
google_api_key = os.getenv("GOOGLE_API_KEY")
gemini = OpenAI(base_url=GEMINI_BASE_URL, api_key=google_api_key)
response = gemini.chat.completions.create(model="gemini-3.1-flash-lite", messages= messages)
print(response.choices[0].message.content)
# Out:
# Sea otters hold hands when they sleep so they don’t drift apart. They often form groups called "rafts," and sometimes they’ll even wrap themselves in long strands of kelp to act as an anchor, keeping them stationary while they snooze!

# %%
# And now - let's ask for a question:

question = "Please propose a hard, challenging question to assess someone's IQ. Respond only with the question."
messages = [{"role": "user", "content": question}]

# %%
# ask it - this uses GPT 5.4 mini, still cheap but more powerful than nano

response = gemini.chat.completions.create(model="gemini-3.1-flash-lite", messages= messages)
question = response.choices[0].message.content
print(question)
# Out:
# If a clock strikes six times in five seconds, how many seconds will it take for the same clock to strike twelve times?

# %%
# form a new messages list

messages = [{"role": "user", "content": question}]
messages
# Out:
# [{'role': 'user',
#   'content': 'If a clock strikes six times in five seconds, how many seconds will it take for the same clock to strike twelve times?'}]

# %%
# Ask the model to answer the hard question

response = gemini.chat.completions.create(model="gemini-3.1-flash-lite", messages= messages)
answer = response.choices[0].message.content
print(answer)
# Out:
# To solve this, you need to look at the **intervals** between the strikes, not the strikes themselves.
#
# 1.  **Analyze the first scenario:** To strike 6 times, there are **5 intervals** between the strikes. Since it takes 5 seconds to complete these 5 intervals, each interval lasts **1 second**.
# 2.  **Analyze the second scenario:** To strike 12 times, there are **11 intervals** between the strikes.
# 3.  **Calculate the time:** Since there are 11 intervals and each interval lasts 1 second, it will take **11 seconds**.

# %%
from IPython.display import Markdown, display

display(Markdown(answer))
# Out:
# To solve this, you need to look at the **intervals** between the strikes, not the strikes themselves.
#
# 1.  **Analyze the first scenario:** To strike 6 times, there are **5 intervals** between the strikes. Since it takes 5 seconds to complete these 5 intervals, each interval lasts **1 second**.
# 2.  **Analyze the second scenario:** To strike 12 times, there are **11 intervals** between the strikes.
# 3.  **Calculate the time:** Since there are 11 intervals and each interval lasts 1 second, it will take **11 seconds**.

# %%
message = f"""
Here is a question:
{question}

And here is a possible answer that might be correct or incorrect:
{answer}

Please evaluate if the answer is correct or incorrect.
"""

print(message)

# %%
messages = [{"role": "user", "content": message}]
response = openai.chat.completions.create(model="gpt-5.4", messages=messages)
print(response.choices[0].message.content)

# %% [markdown]
# # Congratulations!
#
# That was a small, simple step in the direction of Agentic AI, with your new environment!
#
# Next time things get more interesting...

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/exercise.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Exercise</h2>
#             <span style="color:#ff7800;">Now try this commercial application:<br/>
#             First ask the LLM to pick a business area that might be worth exploring for an Agentic AI opportunity.<br/>
#             Then ask the LLM to present a pain-point in that industry - something challenging that might be ripe for an Agentic solution.<br/>
#             Finally have 3 third LLM call propose the Agentic AI solution. <br/>
#             We will cover this at up-coming labs, so don't worry if you're unsure.. just give it a try!
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# First create the messages:

messages = [{"role": "user", "content": "give me only one business idea might be good for agentic ai"}]

# Then make the first call:

response = gemini.chat.completions.create(model="gemini-3.1-flash-lite", messages= messages)

# Then read the business idea:

business_area = response.choices[0].message.content


# And repeat! In the next message, include the business area within the message

# %%
print(business_area)
# Out:
# **Automated Procurement and Vendor Management Agent**
#
# This agent autonomously manages a company’s purchasing lifecycle by monitoring inventory levels, comparing real-time pricing across multiple B2B marketplaces, negotiating contract terms with suppliers via email, executing orders, and reconciling invoices with purchase orders—all without human intervention until a final approval or exception threshold is triggered.

# %%
message  = f"""
Here is a business idea:
{business_area}

Please propose a pain-point in that industry - something challenging that might be ripe for an Agentic solution.
"""
messages = [{"role": "user", "content": message}]

response = gemini.chat.completions.create(model="gemini-3.1-flash-lite", messages= messages)
print(response.choices[0].message.content)
# Out:
# The most significant pain point in procurement that is ripe for an Agentic solution is **"Maverick Spend" and the "Shadow Procurement" loop.**
#
# ### The Problem: The "Wild West" of Decentralized Purchasing
# In most mid-to-large enterprises, procurement processes are slow, bureaucratic, and often circumvented. Employees frequently buy goods or services directly (e.g., using a company credit card on Amazon, software subscriptions without IT approval, or hiring local contractors) to bypass the "official" procurement department.
#
# This creates three massive, expensive headaches:
#
# 1.  **Contract Leakage:** The company has pre-negotiated volume discounts with specific vendors, but employees keep buying from retail sites at 30–40% higher costs because it’s "easier."
# 2.  **Compliance and Risk Blindness:** When employees buy off-contract, they often ignore security reviews, data privacy requirements (GDPR/SOC2), and ESG mandates. The company has no idea what tools or materials are entering their ecosystem.
# 3.  **The Reconciliation Nightmare:** Accounts Payable (AP) departments spend thousands of hours manually chasing down receipts, matching them to purchase orders that don't exist, and trying to categorize "mystery charges" that appear on corporate credit card statements.
#
# ---
#
# ### Why this is perfect for an Agentic Solution
# Existing procurement software (like Coupa or SAP Ariba) is **passive.** It is a gatekeeper that says "No" or "Fill out this 10-page form." It relies on humans to do the heavy lifting of compliance.
#
# An **Agentic solution** flips this by being **proactive and frictionless.** Here is how an Agent solves the "Maverick Spend" pain point:
#
# *   **The Intent Interception:** Instead of forcing employees to use a clunky portal, the Agent lives in the communication flow (Slack/Microsoft Teams). When an employee types, *"I need a new laptop stand,"* the Agent doesn't just block them; it autonomously pulls the pre-approved options from a preferred vendor list, applies the enterprise discount, and asks: *"Shall I order the one that fits our sustainability policy and is already in the approved catalog?"*
# *   **Contextual Negotiation:** If an employee asks for a piece of software that isn't on the approved list, the Agent doesn't just decline. It autonomously sends an email to the vendor’s sales bot: *"We are interested in your product, but we require a BAA for HIPAA compliance. Can you provide this and match our standard payment terms?"* The Agent handles the back-and-forth negotiation, effectively becoming a procurement officer that works at the speed of chat.
# *   **Shadow IT Discovery:** The Agent can periodically scan corporate card logs or browser extensions, detect the "maverick" purchases, and autonomously reach out to the vendor to "bring them into the fold"—essentially automating the onboarding of new suppliers so they become *approved* vendors rather than *unauthorized* ones.
#
# ### The "Killer" Value Proposition
# The reason this is ripe for disruption is that **humans are currently acting as the bridge between systems.**
#
# By deploying an Agentic solution, you aren't just building a software tool; you are building an **Autonomous Procurement Analyst.** You solve the pain point by making the *official* way of buying goods the *easiest* way of buying goods, while simultaneously enforcing enterprise governance in the background.
#
# **This turns procurement from a "department of no" into a "department of frictionless operations."**
